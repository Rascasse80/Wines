# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Métodos de Validación
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# Modelos de Clasificación
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

# Métricas para Clasificación
from sklearn.metrics import jaccard_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# OverSampling y UnderSampling
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

import sklearn
from sklearn.cluster import KMeans

from collections import Counter
from imblearn.over_sampling import SMOTE 
from imblearn.under_sampling import RandomUnderSampler

import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv("winequality-red.csv", sep=';')
df2 = pd.read_csv("winequality-white.csv", sep=';')

# %%
df2["white"]=1
df2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df1["white"]=0
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_vinos = pd.concat([df1, df2])
df_vinos
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ### Predicción blanco/tinto

# %%
X = df_vinos.drop('white', axis=1)
y = np.array(df_vinos['white'])

X.shape, y.shape
# Out:
# ((6497, 12), (6497,))

# %%
undersampling = RandomUnderSampler(sampling_strategy = 0.5)
X_balanceado, y_balanceado = undersampling.fit_resample(X, y)

# %%
x_scaler = MinMaxScaler()

X = x_scaler.fit_transform(X_balanceado)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_balanceado, test_size = 0.20, random_state = 42)

print(f"Conjunto de Train: {X_train.shape, y_train.shape}")
print(f"Conjunto de Test: {X_test.shape, y_test.shape}")
# Out:
# Conjunto de Train: ((3837, 12), (3837,))
# Conjunto de Test: ((960, 12), (960,))

# %%
models = [KNeighborsClassifier(), NearestCentroid(), GaussianNB(), LogisticRegression(),
         DecisionTreeClassifier(), RandomForestClassifier(), SVC(), GradientBoostingClassifier(), AdaBoostClassifier()]

# %%
datos_metricas = list()

for model in models:
    model.fit(X_train, y_train.ravel())
    
    yhat = model.predict(X_test)
    
    Jaccard_Index = jaccard_score(y_test, yhat, average = "macro")
    Exactitud = accuracy_score(y_test, yhat)
    Precision = precision_score(y_test, yhat, average = "macro")
    Sensibilidad = recall_score(y_test, yhat, average = "macro")
    F1_score = f1_score(y_test, yhat, average = "macro")
    
    datos_metricas.append([model, str(model).rstrip("()"), Jaccard_Index, Exactitud, Precision, Sensibilidad, F1_score])
    
df_metricas = pd.DataFrame(data = datos_metricas, columns = ["Model", "Modelo", "Jaccard_Index", "Exactitud", "Precision", 
                                                             "Sensibilidad", "F1_score"])

# %%
best_model = df_metricas.sort_values("F1_score", ascending = False)["Model"].iloc[0]

best_model
# Out:
# RandomForestClassifier()

# %%
df_metricas.drop("Model", axis = 1, inplace = True)
df_metricas.sort_values("F1_score", ascending = False)
# Out:
#                        Modelo  Jaccard_Index  Exactitud  Precision  \
# 5      RandomForestClassifier       0.981985   0.991667   0.990904
# 8          AdaBoostClassifier       0.979797   0.990625   0.988844
# 7  GradientBoostingClassifier       0.979719   0.990625   0.990739
# 6                         SVC       0.977478   0.989583   0.989931
# 0        KNeighborsClassifier       0.962252   0.982292   0.979218
# 3          LogisticRegression       0.961963   0.982292   0.982930
# 4      DecisionTreeClassifier       0.951411   0.977083   0.973842
# 2                  GaussianNB       0.942987   0.972917   0.968280
# 1             NearestCentroid       0.926398   0.964583   0.957933
#
#    Sensibilidad  F1_score
# 5      0.990904  0.990904
# 8      0.990755  0.989787
# 7      0.988779  0.989746
# 6      0.987313  0.988600
# 0      0.982317  0.980734
# 3      0.978366  0.980580
# 4      0.976303  0.975051
# 2      0.973072  0.970590
# 1      0.965951  0.961686

# %%
# Stratified k-Fold

skfold = StratifiedKFold(n_splits = 10)
y_test_real, yhat = list(), list()


for train_index, test_index in skfold.split(X, y_balanceado): 
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # Modelo
    modelo = best_model
    modelo.fit(X_train, y_train)
    
    # Prediccion
    yhat1 = modelo.predict(X_test)
    yhat.extend(yhat1)
    
    # Valores reales
    y_test_real.extend(y_test)

print("Accuracy:", accuracy_score(y_test_real, yhat))
# Out:
# Accuracy: 0.9929122368146759

# %%
# No aplicamos GridSearch porque los resultados del modelo sin tunear ya son bastante buenos

# %% [markdown]
# ### Predición calidad

# %%
X2 = df_vinos.drop(['quality', 'white'], axis=1)
y2 = np.array(df_vinos['quality'])

X2.shape, y2.shape
# Out:
# ((6497, 11), (6497,))

# %%
X2 = x_scaler.fit_transform(X2)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size = 0.30, random_state = 45)

# %%
datos_metricas2 = list()

for modelo in models:
    modelo.fit(X_train2, y_train2.ravel())
    
    yhat2 = modelo.predict(X_test2)
    
    Jaccard_Index2 = jaccard_score(y_test2, yhat2, average = "macro")
    Exactitud2 = accuracy_score(y_test2, yhat2)
    Precision2 = precision_score(y_test2, yhat2, average = "macro")
    Sensibilidad2 = recall_score(y_test2, yhat2, average = "macro")
    F1_score2 = f1_score(y_test2, yhat2, average = "macro")
    
    datos_metricas2.append([modelo, str(modelo).rstrip("()"), Jaccard_Index2, Exactitud2, Precision2, Sensibilidad2, F1_score2])
    
df_metricas2 = pd.DataFrame(data = datos_metricas2, columns = ["Model", "Modelo", "Jaccard_Index", "Exactitud", "Precision", 
                                                             "Sensibilidad", "F1_score"])

# %%
mejor_modelo = df_metricas2.sort_values("F1_score", ascending = False)["Model"].iloc[0]

mejor_modelo
# Out:
# RandomForestClassifier()

# %%
df_metricas2.drop("Model", axis = 1, inplace = True)
df_metricas2.sort_values("F1_score", ascending = False)
# Out:
#                        Modelo  Jaccard_Index  Exactitud  Precision  \
# 5      RandomForestClassifier       0.291367   0.686667   0.536262
# 4      DecisionTreeClassifier       0.235752   0.592821   0.335621
# 7  GradientBoostingClassifier       0.224283   0.606667   0.406755
# 0        KNeighborsClassifier       0.187720   0.547692   0.319205
# 2                  GaussianNB       0.159140   0.458974   0.270151
# 6                         SVC       0.147694   0.563077   0.264980
# 3          LogisticRegression       0.143951   0.545641   0.240906
# 1             NearestCentroid       0.095774   0.245128   0.214713
# 8          AdaBoostClassifier       0.093999   0.337949   0.197949
#
#    Sensibilidad  F1_score
# 5      0.362589  0.399352
# 4      0.350590  0.341852
# 7      0.301929  0.326737
# 0      0.268861  0.280176
# 2      0.254828  0.249083
# 6      0.219124  0.209327
# 3      0.215373  0.207128
# 1      0.351279  0.164206
# 8      0.203698  0.152976

# %%
# Stratified k-Fold

y_test_real2, yhat2 = list(), list()


for train_index, test_index in skfold.split(X2, y2): 
    X_train2, X_test2 = X2[train_index], X2[test_index]
    y_train2, y_test2 = y2[train_index], y2[test_index]
    
    # Modelo
    modelo = mejor_modelo
    modelo.fit(X_train2, y_train2)
    
    # Prediccion
    yhat_aux = modelo.predict(X_test2)
    yhat2.extend(yhat_aux)
    
    # Valores reales
    y_test_real2.extend(y_test2)

print("Accuracy:", accuracy_score(y_test_real2, yhat2))
# Out:
# Accuracy: 0.49545944281976295
